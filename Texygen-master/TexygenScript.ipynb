# %%
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 200 -i 1
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 400 -i 1
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 600 -i 1
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 800 -i 1
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 1000 -i 1
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 200 -i 1
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 400 -i 1
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 600 -i 1
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 800 -i 1
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 1000 -i 1
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 200 -i 1
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 400 -i 1
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 600 -i 1
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 800 -i 1
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 1000 -i 1
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 200 -i 1
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 400 -i 1
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 600 -i 1
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 800 -i 1
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 1000 -i 1
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 200 -i 1
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 400 -i 1
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 600 -i 1
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 800 -i 1
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 1000 -i 1
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 200 -i 2
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 400 -i 2
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 600 -i 2
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 800 -i 2
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 1000 -i 2
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 200 -i 2
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 400 -i 2
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 600 -i 2
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 800 -i 2
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 1000 -i 2
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 200 -i 2
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 400 -i 2
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 600 -i 2
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 800 -i 2
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 1000 -i 2
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 200 -i 2
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 400 -i 2
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 600 -i 2
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 800 -i 2
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 1000 -i 2
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 200 -i 2
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 400 -i 2
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 600 -i 2
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 800 -i 2
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 1000 -i 2
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 200 -i 3
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 400 -i 3
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 600 -i 3
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 800 -i 3
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 1000 -i 3
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 200 -i 3
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 400 -i 3
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 600 -i 3
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 800 -i 3
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 1000 -i 3
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 200 -i 3
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 400 -i 3
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 600 -i 3
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 800 -i 3
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 1000 -i 3
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 200 -i 3
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 400 -i 3
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 600 -i 3
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 800 -i 3
# !python main.py -g leakgan -t real -d data/processed_data_text.txt -s 1000 -i 3
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 200 -i 3
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 400 -i 3
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 600 -i 3
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 800 -i 3
# !python main.py -g mle -t real -d data/processed_data_text.txt -s 1000 -i 3
# Out:
# ('opt_arg', {'-t': 'real', '-g': 'seqgan', '-i': '1', '-s': '200', '-d': 'data/processed_data_text.txt'})
# 2019-03-13 11:53:12.031792: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-03-13 11:53:13.997385: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-13 11:53:13.997866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-03-13 11:53:13.997909: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# ...

# %%
gans = ['seqgan','gsgan','textgan','leakgan','mle']
datasets = ['emnlp', 'coco']
sizes = ['200', '400', '600', '800', '1000']

for i in range(3):
    for gan in gans:
        for s in sizes:
            name = '!python main.py -g '+gan+' -t real -d data/processed_data_text.txt -s '+str(s)+' -i '+str(i+1)
            print(name)
# Out:
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 200 -i 1
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 400 -i 1
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 600 -i 1
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 800 -i 1
# !python main.py -g seqgan -t real -d data/processed_data_text.txt -s 1000 -i 1
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 200 -i 1
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 400 -i 1
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 600 -i 1
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 800 -i 1
# !python main.py -g gsgan -t real -d data/processed_data_text.txt -s 1000 -i 1
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 200 -i 1
# !python main.py -g textgan -t real -d data/processed_data_text.txt -s 400 -i 1
# ...
